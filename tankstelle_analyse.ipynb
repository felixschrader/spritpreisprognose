# %%
'''import subprocess

USER = 'felix.schrader_posteo.de'
PASS = '' #API-Key einfügen

result = subprocess.run(
    ['git', 'pull', f'https://{USER}:{PASS}@data.tankerkoenig.de/tankerkoenig-organization/tankerkoenig-data.git'],
    cwd='/media/rex/6DFF-26FE/Tankerkoenig',
    capture_output=True,
    text=True
)
print(result.stdout if result.stdout else '(keine Ausgabe)')
print(result.stderr if result.stderr else '')'''
# Out:
# Aktualisiere 5b561f9..2bc65bd
# Fast-forward
#  prices/2026/01/2026-01-17-prices.csv     | 461500 +++++++++++++++++++++++++
#  prices/2026/01/2026-01-18-prices.csv     | 436210 ++++++++++++++++++++++++
#  prices/2026/01/2026-01-19-prices.csv     | 494291 +++++++++++++++++++++++++++
#  prices/2026/01/2026-01-20-prices.csv     | 494379 +++++++++++++++++++++++++++
#  prices/2026/01/2026-01-21-prices.csv     | 465005 +++++++++++++++++++++++++
#  prices/2026/01/2026-01-22-prices.csv     | 484629 ++++++++++++++++++++++++++
#  prices/2026/01/2026-01-23-prices.csv     | 476959 ++++++++++++++++++++++++++
#  prices/2026/01/2026-01-24-prices.csv     | 457160 +++++++++++++++++++++++++
#  prices/2026/01/2026-01-25-prices.csv     | 422780 +++++++++++++++++++++++
#  prices/2026/01/2026-01-26-prices.csv     | 362590 ++++++++++++++++++++
#  prices/2026/01/2026-01-27-prices.csv     | 472578 ++++++++++++++++++++++++++
#  prices/2026/01/2026-01-28-prices.csv     | 494191 +++++++++++++++++++++++++++
#  prices/2026/01/2026-01-29-prices.csv     | 491902 +++++++++++++++++++++++++++
#  prices/2026/01/2026-01-30-prices.csv     | 468823 +++++++++++++++++++++++++
#  prices/2026/01/2026-01-31-prices.csv     | 447641 ++++++++++++++++++++++++
#  prices/2026/02/2026-02-01-prices.csv     | 433878 ++++++++++++++++++++++++
#  prices/2026/02/2026-02-02-prices.csv     | 461444 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-03-prices.csv     | 494801 +++++++++++++++++++++++++++
#  prices/2026/02/2026-02-04-prices.csv     | 474434 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-05-prices.csv     | 448597 ++++++++++++++++++++++++
#  prices/2026/02/2026-02-06-prices.csv     | 452309 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-07-prices.csv     | 471922 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-08-prices.csv     | 421091 +++++++++++++++++++++++
#  prices/2026/02/2026-02-09-prices.csv     | 489928 +++++++++++++++++++++++++++
#  prices/2026/02/2026-02-10-prices.csv     | 484089 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-11-prices.csv     | 497237 +++++++++++++++++++++++++++
#  prices/2026/02/2026-02-12-prices.csv     | 471039 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-13-prices.csv     | 486613 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-14-prices.csv     | 469940 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-15-prices.csv     | 441492 ++++++++++++++++++++++++
#  prices/2026/02/2026-02-16-prices.csv     | 508205 ++++++++++++++++++++++++++++
#  prices/2026/02/2026-02-17-prices.csv     | 493716 +++++++++++++++++++++++++++
#  prices/2026/02/2026-02-18-prices.csv     | 470057 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-19-prices.csv     | 495557 +++++++++++++++++++++++++++
#  prices/2026/02/2026-02-20-prices.csv     | 453484 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-21-prices.csv     | 450391 ++++++++++++++++++++++++
#  prices/2026/02/2026-02-22-prices.csv     | 406857 ++++++++++++++++++++++
#  prices/2026/02/2026-02-23-prices.csv     | 487884 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-24-prices.csv     | 464408 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-25-prices.csv     | 470937 ++++++++++++++++++++++++++
#  prices/2026/02/2026-02-26-prices.csv     | 452497 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-27-prices.csv     | 470297 +++++++++++++++++++++++++
#  prices/2026/02/2026-02-28-prices.csv     | 455177 +++++++++++++++++++++++++
#  prices/2026/03/2026-03-01-prices.csv     | 430848 +++++++++++++++++++++++
#  prices/2026/03/2026-03-02-prices.csv     | 379298 +++++++++++++++++++++
#  prices/2026/03/2026-03-03-prices.csv     | 393931 +++++++++++++++++++++
#  prices/2026/03/2026-03-04-prices.csv     | 437827 ++++++++++++++++++++++++
#  prices/2026/03/2026-03-05-prices.csv     | 461264 +++++++++++++++++++++++++
#  prices/2026/03/2026-03-06-prices.csv     | 429754 +++++++++++++++++++++++
#  prices/2026/03/2026-03-07-prices.csv     | 428603 +++++++++++++++++++++++
#  prices/2026/03/2026-03-08-prices.csv     | 414120 +++++++++++++++++++++++
#  prices/2026/03/2026-03-09-prices.csv     | 375900 ++++++++++++++++++++
#  prices/2026/03/2026-03-10-prices.csv     | 448557 ++++++++++++++++++++++++
#  prices/2026/03/2026-03-11-prices.csv     | 458575 +++++++++++++++++++++++++
#  stations/2026/01/2026-01-17-stations.csv |  17719 +
#  stations/2026/01/2026-01-18-stations.csv |  17719 +
#  stations/2026/01/2026-01-19-stations.csv |  17719 +
#  stations/2026/01/2026-01-20-stations.csv |  17721 +
#  stations/2026/01/2026-01-21-stations.csv |  17721 +
#  stations/2026/01/2026-01-22-stations.csv |  17723 +
#  stations/2026/01/2026-01-23-stations.csv |  17723 +
#  stations/2026/01/2026-01-24-stations.csv |  17723 +
#  stations/2026/01/2026-01-25-stations.csv |  17724 +
#  stations/2026/01/2026-01-26-stations.csv |  17724 +
#  stations/2026/01/2026-01-27-stations.csv |  17724 +
#  stations/2026/01/2026-01-28-stations.csv |  17724 +
#  stations/2026/01/2026-01-29-stations.csv |  17724 +
#  stations/2026/01/2026-01-30-stations.csv |  17724 +
#  stations/2026/01/2026-01-31-stations.csv |  17726 +
#  stations/2026/02/2026-02-01-stations.csv |  17726 +
#  stations/2026/02/2026-02-02-stations.csv |  17726 +
#  stations/2026/02/2026-02-03-stations.csv |  17727 +
#  stations/2026/02/2026-02-04-stations.csv |  17728 +
#  stations/2026/02/2026-02-05-stations.csv |  17728 +
#  stations/2026/02/2026-02-06-stations.csv |  17731 +
#  stations/2026/02/2026-02-07-stations.csv |  17731 +
#  stations/2026/02/2026-02-08-stations.csv |  17731 +
#  stations/2026/02/2026-02-09-stations.csv |  17731 +
#  stations/2026/02/2026-02-10-stations.csv |  17731 +
#  stations/2026/02/2026-02-11-stations.csv |  17732 +
#  stations/2026/02/2026-02-12-stations.csv |  17732 +
#  stations/2026/02/2026-02-13-stations.csv |  17732 +
#  stations/2026/02/2026-02-14-stations.csv |  17732 +
#  stations/2026/02/2026-02-15-stations.csv |  17732 +
#  stations/2026/02/2026-02-16-stations.csv |  17732 +
#  stations/2026/02/2026-02-17-stations.csv |  17732 +
#  stations/2026/02/2026-02-18-stations.csv |  17733 +
#  stations/2026/02/2026-02-19-stations.csv |  17736 +
#  stations/2026/02/2026-02-20-stations.csv |  17736 +
#  stations/2026/02/2026-02-21-stations.csv |  17736 +
#  stations/2026/02/2026-02-22-stations.csv |  17736 +
#  stations/2026/02/2026-02-23-stations.csv |  17736 +
#  stations/2026/02/2026-02-24-stations.csv |  17737 +
#  stations/2026/02/2026-02-25-stations.csv |  17738 +
#  stations/2026/02/2026-02-26-stations.csv |  17739 +
#  stations/2026/02/2026-02-27-stations.csv |  17739 +
#  stations/2026/02/2026-02-28-stations.csv |  17739 +
#  stations/2026/03/2026-03-01-stations.csv |  17739 +
#  stations/2026/03/2026-03-02-stations.csv |  17739 +
#  stations/2026/03/2026-03-03-stations.csv |  17743 +
#  stations/2026/03/2026-03-04-stations.csv |  17743 +
#  stations/2026/03/2026-03-05-stations.csv |  17743 +
#  stations/2026/03/2026-03-06-stations.csv |  17743 +
#  stations/2026/03/2026-03-07-stations.csv |  17744 +
#  stations/2026/03/2026-03-08-stations.csv |  17744 +
#  stations/2026/03/2026-03-09-stations.csv |  17744 +
#  stations/2026/03/2026-03-10-stations.csv |  17744 +
#  stations/2026/03/2026-03-11-stations.csv |  17745 +
#  108 files changed, 25625124 insertions(+)
#  create mode 100644 prices/2026/01/2026-01-17-prices.csv
#  create mode 100644 prices/2026/01/2026-01-18-prices.csv
#  create mode 100644 prices/2026/01/2026-01-19-prices.csv
#  create mode 100644 prices/2026/01/2026-01-20-prices.csv
#  create mode 100644 prices/2026/01/2026-01-21-prices.csv
#  create mode 100644 prices/2026/01/2026-01-22-prices.csv
#  create mode 100644 prices/2026/01/2026-01-23-prices.csv
#  create mode 100644 prices/2026/01/2026-01-24-prices.csv
#  create mode 100644 prices/2026/01/2026-01-25-prices.csv
#  create mode 100644 prices/2026/01/2026-01-26-prices.csv
#  create mode 100644 prices/2026/01/2026-01-27-prices.csv
#  create mode 100644 prices/2026/01/2026-01-28-prices.csv
#  create mode 100644 prices/2026/01/2026-01-29-prices.csv
#  create mode 100644 prices/2026/01/2026-01-30-prices.csv
#  create mode 100644 prices/2026/01/2026-01-31-prices.csv
#  create mode 100644 prices/2026/02/2026-02-01-prices.csv
#  create mode 100644 prices/2026/02/2026-02-02-prices.csv
#  create mode 100644 prices/2026/02/2026-02-03-prices.csv
#  create mode 100644 prices/2026/02/2026-02-04-prices.csv
#  create mode 100644 prices/2026/02/2026-02-05-prices.csv
#  create mode 100644 prices/2026/02/2026-02-06-prices.csv
#  create mode 100644 prices/2026/02/2026-02-07-prices.csv
#  create mode 100644 prices/2026/02/2026-02-08-prices.csv
#  create mode 100644 prices/2026/02/2026-02-09-prices.csv
#  create mode 100644 prices/2026/02/2026-02-10-prices.csv
#  create mode 100644 prices/2026/02/2026-02-11-prices.csv
#  create mode 100644 prices/2026/02/2026-02-12-prices.csv
#  create mode 100644 prices/2026/02/2026-02-13-prices.csv
#  create mode 100644 prices/2026/02/2026-02-14-prices.csv
#  create mode 100644 prices/2026/02/2026-02-15-prices.csv
#  create mode 100644 prices/2026/02/2026-02-16-prices.csv
#  create mode 100644 prices/2026/02/2026-02-17-prices.csv
#  create mode 100644 prices/2026/02/2026-02-18-prices.csv
#  create mode 100644 prices/2026/02/2026-02-19-prices.csv
#  create mode 100644 prices/2026/02/2026-02-20-prices.csv
#  create mode 100644 prices/2026/02/2026-02-21-prices.csv
#  create mode 100644 prices/2026/02/2026-02-22-prices.csv
#  create mode 100644 prices/2026/02/2026-02-23-prices.csv
#  create mode 100644 prices/2026/02/2026-02-24-prices.csv
#  create mode 100644 prices/2026/02/2026-02-25-prices.csv
#  create mode 100644 prices/2026/02/2026-02-26-prices.csv
#  create mode 100644 prices/2026/02/2026-02-27-prices.csv
#  create mode 100644 prices/2026/02/2026-02-28-prices.csv
#  create mode 100644 prices/2026/03/2026-03-01-prices.csv
#  create mode 100644 prices/2026/03/2026-03-02-prices.csv
#  create mode 100644 prices/2026/03/2026-03-03-prices.csv
#  create mode 100644 prices/2026/03/2026-03-04-prices.csv
#  create mode 100644 prices/2026/03/2026-03-05-prices.csv
#  create mode 100644 prices/2026/03/2026-03-06-prices.csv
#  create mode 100644 prices/2026/03/2026-03-07-prices.csv
#  create mode 100644 prices/2026/03/2026-03-08-prices.csv
#  create mode 100644 prices/2026/03/2026-03-09-prices.csv
#  create mode 100644 prices/2026/03/2026-03-10-prices.csv
#  create mode 100644 prices/2026/03/2026-03-11-prices.csv
#  create mode 100644 stations/2026/01/2026-01-17-stations.csv
#  create mode 100644 stations/2026/01/2026-01-18-stations.csv
#  create mode 100644 stations/2026/01/2026-01-19-stations.csv
#  create mode 100644 stations/2026/01/2026-01-20-stations.csv
#  create mode 100644 stations/2026/01/2026-01-21-stations.csv
#  create mode 100644 stations/2026/01/2026-01-22-stations.csv
#  create mode 100644 stations/2026/01/2026-01-23-stations.csv
#  create mode 100644 stations/2026/01/2026-01-24-stations.csv
#  create mode 100644 stations/2026/01/2026-01-25-stations.csv
#  create mode 100644 stations/2026/01/2026-01-26-stations.csv
#  create mode 100644 stations/2026/01/2026-01-27-stations.csv
#  create mode 100644 stations/2026/01/2026-01-28-stations.csv
#  create mode 100644 stations/2026/01/2026-01-29-stations.csv
#  create mode 100644 stations/2026/01/2026-01-30-stations.csv
#  create mode 100644 stations/2026/01/2026-01-31-stations.csv
#  create mode 100644 stations/2026/02/2026-02-01-stations.csv
#  create mode 100644 stations/2026/02/2026-02-02-stations.csv
#  create mode 100644 stations/2026/02/2026-02-03-stations.csv
#  create mode 100644 stations/2026/02/2026-02-04-stations.csv
#  create mode 100644 stations/2026/02/2026-02-05-stations.csv
#  create mode 100644 stations/2026/02/2026-02-06-stations.csv
#  create mode 100644 stations/2026/02/2026-02-07-stations.csv
#  create mode 100644 stations/2026/02/2026-02-08-stations.csv
#  create mode 100644 stations/2026/02/2026-02-09-stations.csv
#  create mode 100644 stations/2026/02/2026-02-10-stations.csv
#  create mode 100644 stations/2026/02/2026-02-11-stations.csv
#  create mode 100644 stations/2026/02/2026-02-12-stations.csv
#  create mode 100644 stations/2026/02/2026-02-13-stations.csv
#  create mode 100644 stations/2026/02/2026-02-14-stations.csv
#  create mode 100644 stations/2026/02/2026-02-15-stations.csv
#  create mode 100644 stations/2026/02/2026-02-16-stations.csv
#  create mode 100644 stations/2026/02/2026-02-17-stations.csv
#  create mode 100644 stations/2026/02/2026-02-18-stations.csv
#  create mode 100644 stations/2026/02/2026-02-19-stations.csv
#  create mode 100644 stations/2026/02/2026-02-20-stations.csv
#  create mode 100644 stations/2026/02/2026-02-21-stations.csv
#  create mode 100644 stations/2026/02/2026-02-22-stations.csv
#  create mode 100644 stations/2026/02/2026-02-23-stations.csv
#  create mode 100644 stations/2026/02/2026-02-24-stations.csv
#  create mode 100644 stations/2026/02/2026-02-25-stations.csv
#  create mode 100644 stations/2026/02/2026-02-26-stations.csv
#  create mode 100644 stations/2026/02/2026-02-27-stations.csv
#  create mode 100644 stations/2026/02/2026-02-28-stations.csv
#  create mode 100644 stations/2026/03/2026-03-01-stations.csv
#  create mode 100644 stations/2026/03/2026-03-02-stations.csv
#  create mode 100644 stations/2026/03/2026-03-03-stations.csv
#  create mode 100644 stations/2026/03/2026-03-04-stations.csv
#  create mode 100644 stations/2026/03/2026-03-05-stations.csv
#  create mode 100644 stations/2026/03/2026-03-06-stations.csv
#  create mode 100644 stations/2026/03/2026-03-07-stations.csv
#  create mode 100644 stations/2026/03/2026-03-08-stations.csv
#  create mode 100644 stations/2026/03/2026-03-09-stations.csv
#  create mode 100644 stations/2026/03/2026-03-10-stations.csv
#  create mode 100644 stations/2026/03/2026-03-11-stations.csv
#
# Von https://data.tankerkoenig.de/tankerkoenig-organization/tankerkoenig-data
#  * branch            HEAD       -> FETCH_HEAD
# Aktualisiere Dateien:   2% (3/108)
# Aktualisiere Dateien:   3% (4/108)
# Aktualisiere Dateien:   4% (5/108)
# Aktualisiere Dateien:   5% (6/108)
# Aktualisiere Dateien:   6% (7/108)
# Aktualisiere Dateien:   7% (8/108)
# Aktualisiere Dateien:   8% (9/108)
# Aktualisiere Dateien:   9% (10/108)
# Aktualisiere Dateien:  10% (11/108)
# Aktualisiere Dateien:  11% (12/108)
# Aktualisiere Dateien:  12% (13/108)
# Aktualisiere Dateien:  12% (14/108)
# Aktualisiere Dateien:  13% (15/108)
# Aktualisiere Dateien:  14% (16/108)
# Aktualisiere Dateien:  15% (17/108)
# Aktualisiere Dateien:  16% (18/108)
# Aktualisiere Dateien:  17% (19/108)
# Aktualisiere Dateien:  18% (20/108)
# Aktualisiere Dateien:  19% (21/108)
# Aktualisiere Dateien:  20% (22/108)
# Aktualisiere Dateien:  21% (23/108)
# Aktualisiere Dateien:  22% (24/108)
# Aktualisiere Dateien:  23% (25/108)
# Aktualisiere Dateien:  24% (26/108)
# Aktualisiere Dateien:  25% (27/108)
# Aktualisiere Dateien:  26% (29/108)
# Aktualisiere Dateien:  27% (30/108)
# Aktualisiere Dateien:  28% (31/108)
# Aktualisiere Dateien:  29% (32/108)
# Aktualisiere Dateien:  30% (33/108)
# Aktualisiere Dateien:  31% (34/108)
# Aktualisiere Dateien:  32% (35/108)
# Aktualisiere Dateien:  33% (36/108)
# Aktualisiere Dateien:  34% (37/108)
# Aktualisiere Dateien:  35% (38/108)
# Aktualisiere Dateien:  36% (39/108)
# Aktualisiere Dateien:  37% (40/108)
# Aktualisiere Dateien:  38% (42/108)
# Aktualisiere Dateien:  39% (43/108)
# Aktualisiere Dateien:  40% (44/108)
# Aktualisiere Dateien:  41% (45/108)
# Aktualisiere Dateien:  42% (46/108)
# Aktualisiere Dateien:  43% (47/108)
# Aktualisiere Dateien:  44% (48/108)
# Aktualisiere Dateien:  45% (49/108)
# Aktualisiere Dateien:  46% (50/108)
# Aktualisiere Dateien:  47% (51/108)
# Aktualisiere Dateien:  48% (52/108)
# Aktualisiere Dateien:  49% (53/108)
# Aktualisiere Dateien:  50% (54/108)
# Aktualisiere Dateien:  51% (56/108)
# Aktualisiere Dateien:  52% (57/108)
# Aktualisiere Dateien:  53% (58/108)
# Aktualisiere Dateien:  54% (59/108)
# Aktualisiere Dateien:  55% (60/108)
# Aktualisiere Dateien:  56% (61/108)
# Aktualisiere Dateien:  57% (62/108)
# Aktualisiere Dateien:  58% (63/108)
# Aktualisiere Dateien:  59% (64/108)
# Aktualisiere Dateien:  60% (65/108)
# Aktualisiere Dateien:  61% (66/108)
# Aktualisiere Dateien:  62% (67/108)
# Aktualisiere Dateien:  63% (69/108)
# Aktualisiere Dateien:  64% (70/108)
# Aktualisiere Dateien:  65% (71/108)
# Aktualisiere Dateien:  66% (72/108)
# Aktualisiere Dateien:  67% (73/108)
# Aktualisiere Dateien:  68% (74/108)
# Aktualisiere Dateien:  69% (75/108)
# Aktualisiere Dateien:  70% (76/108)
# Aktualisiere Dateien:  71% (77/108)
# Aktualisiere Dateien:  72% (78/108)
# Aktualisiere Dateien:  73% (79/108)
# Aktualisiere Dateien:  74% (80/108)
# Aktualisiere Dateien:  75% (81/108)
# Aktualisiere Dateien:  76% (83/108)
# Aktualisiere Dateien:  77% (84/108)
# Aktualisiere Dateien:  78% (85/108)
# Aktualisiere Dateien:  79% (86/108)
# Aktualisiere Dateien:  80% (87/108)
# Aktualisiere Dateien:  81% (88/108)
# Aktualisiere Dateien:  82% (89/108)
# Aktualisiere Dateien:  83% (90/108)
# Aktualisiere Dateien:  84% (91/108)
# Aktualisiere Dateien:  85% (92/108)
# Aktualisiere Dateien:  86% (93/108)
# Aktualisiere Dateien:  87% (94/108)
# Aktualisiere Dateien:  88% (96/108)
# Aktualisiere Dateien:  89% (97/108)
# Aktualisiere Dateien:  90% (98/108)
# Aktualisiere Dateien:  91% (99/108)
# Aktualisiere Dateien:  92% (100/108)
# Aktualisiere Dateien:  93% (101/108)
# Aktualisiere Dateien:  94% (102/108)
# Aktualisiere Dateien:  95% (103/108)
# Aktualisiere Dateien:  96% (104/108)
# Aktualisiere Dateien:  97% (105/108)
# Aktualisiere Dateien:  98% (106/108)
# Aktualisiere Dateien:  99% (107/108)
# Aktualisiere Dateien: 100% (108/108)
# Aktualisiere Dateien: 100% (108/108), fertig.

# %% [markdown]
# # ⛽ Tankstellen-Preisanalyse
# Workflow: Tankstelle suchen → UUID übergeben → Preise laden → Analyse → Export

# %%
# ── 0. Imports & Pfade ────────────────────────────────────────────────────
# ── 0. Imports & Pfade ────────────────────────────────────────────────────
import glob, os, time
from pathlib import Path

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output

BASE_DIR     = Path('/media/rex/6DFF-26FE/Tankerkoenig')
PRICES_DIR   = BASE_DIR / 'prices'
STATIONS_CSV = BASE_DIR / 'stations' / 'stations.csv'
CACHE_DIR    = BASE_DIR / 'cache'
EXPORT_DIR   = BASE_DIR / 'export'

CACHE_DIR.mkdir(exist_ok=True)
EXPORT_DIR.mkdir(exist_ok=True)

print('Pfade OK')
print(f'  Stations : {STATIONS_CSV}')
print(f'  Prices   : {PRICES_DIR}')
print(f'  Cache    : {CACHE_DIR}')
print(f'  Export   : {EXPORT_DIR}')
# Out:
# Pfade OK
#   Stations : /media/rex/6DFF-26FE/Tankerkoenig/stations/stations.csv
#   Prices   : /media/rex/6DFF-26FE/Tankerkoenig/prices
#   Cache    : /media/rex/6DFF-26FE/Tankerkoenig/cache
#   Export   : /media/rex/6DFF-26FE/Tankerkoenig/export

# %% [markdown]
# ## 1. Tankstationen laden

# %%
# ── 1. Stationen laden ────────────────────────────────────────────────────
stations = pd.read_csv(STATIONS_CSV, dtype={'uuid': str, 'post_code': str})
print(f'{len(stations):,} Tankstellen geladen')
# Out:
# 15,442 Tankstellen geladen

# %% [markdown]
# ## 2. Tankstelle suchen & UUID wählen

# %%
# ── 2. Suche & Auswahl ────────────────────────────────────────────────────
stadt    = widgets.Text(placeholder='z.B. Hamburg')
marke    = widgets.Text(placeholder='z.B. ARAL')
plz      = widgets.Text(placeholder='z.B. 20095')
strasse  = widgets.Text(placeholder='z.B. Hauptstraße')
button   = widgets.Button(description='Suchen', button_style='primary')
dropdown = widgets.Dropdown(description='Auswahl:', options=[], layout=widgets.Layout(width='700px'))
output   = widgets.Output()

display(widgets.VBox([
    widgets.Label('Stadt:'),  stadt,
    widgets.Label('Marke:'),  marke,
    widgets.Label('PLZ:'),    plz,
    widgets.Label('Straße:'), strasse,
    button, dropdown, output
]))

def suchen(b):
    with output:
        clear_output()
        maske = pd.Series([True] * len(stations))
        if stadt.value:   maske &= stations['city'].str.contains(stadt.value, case=False, na=False)
        if marke.value:   maske &= stations['brand'].str.contains(marke.value, case=False, na=False)
        if plz.value:     maske &= stations['post_code'].str.contains(plz.value, case=False, na=False)
        if strasse.value: maske &= stations['street'].str.contains(strasse.value, case=False, na=False)
        treffer = stations[maske]
        print(f'{len(treffer)} Treffer')
        display(treffer[['uuid','name','brand','street','house_number','post_code','city']].reset_index(drop=True))
        dropdown.options = [
            (f"{r['name']} – {r['street']} {r['house_number']}, {r['city']} ({r['uuid']})", r['uuid'])
            for _, r in treffer.iterrows()
        ]

button.on_click(suchen)
# Out:
# VBox(children=(Label(value='Stadt:'), Text(value='', placeholder='z.B. Hamburg'), Label(value='Marke:'), Text(…

# %%
# ── 2b. UUID übernehmen ───────────────────────────────────────────────────
STATION_UUID = dropdown.value
station_info = stations[stations['uuid'] == STATION_UUID].iloc[0]

print('Gewählte Tankstelle:')
print(f"  Name   : {station_info['name']}")
print(f"  Marke  : {station_info['brand']}")
print(f"  Adresse: {station_info['street']} {station_info['house_number']}, {station_info['post_code']} {station_info['city']}")
print(f"  UUID   : {STATION_UUID}")
# Out:
# Gewählte Tankstelle:
#   Name   : Aral Tankstelle
#   Marke  : ARAL
#   Adresse: Dürener Straße 407, 50858 Köln
#   UUID   : e1aefc4e-3ca1-4018-8d91-455b69d35d41

# %% [markdown]
# ## 3. Preisdaten laden  → Parquet-Cache

# %%
# ── 3. CSVs finden ────────────────────────────────────────────────────────
alle_csvs = sorted(glob.glob(str(PRICES_DIR / '**' / '*.csv'), recursive=True))
print(f'{len(alle_csvs):,} Tagesdateien gefunden ({alle_csvs[0].split("/")[-3]} – {alle_csvs[-1].split("/")[-3]})')
# Out:
# 4,297 Tagesdateien gefunden (2014 – Tankerkoenig)

# %%
'''# Cache löschen (optional) ────────────────────────────────────────────────
import shutil
cache_sub = CACHE_DIR / STATION_UUID
if cache_sub.exists():
    shutil.rmtree(cache_sub)
    print(f'Cache gelöscht: {cache_sub}')
else:
    print('Kein Cache vorhanden')'''
# Out:
# Cache gelöscht: /media/rex/6DFF-26FE/Tankerkoenig/cache/e1aefc4e-3ca1-4018-8d91-455b69d35d41

# %%
# ── 3a. Preise laden & monatsweise cachen ────────────────────────────────
from itertools import groupby

COLS      = ['date','station_uuid','diesel','e5','e10']
cache_sub = CACHE_DIR / STATION_UUID
cache_sub.mkdir(exist_ok=True)

def monat_key(p):
    teile = Path(p).parts
    return f'{teile[-3]}-{teile[-2]}'

monate         = {k: list(v) for k, v in groupby(alle_csvs, monat_key)}
aktueller_monat = sorted(monate.keys())[-1]

# ── hier anpassen: None = alle Monate, oder z.B. ['2026-01'] ─────────────
FILTER_MONATE = ['2025-12','2026-01', '2026-02', '2026-03']

zu_verarbeiten = [
    m for m in sorted(monate.keys())
    if (FILTER_MONATE is None or m in FILTER_MONATE)
    and (not (cache_sub / f'{m}.parquet').exists() or m == aktueller_monat)
]

print(f'{len(monate)} Monate gesamt, {len(zu_verarbeiten)} zu verarbeiten')

gesamt_csvs = sum(len(monate[m]) for m in zu_verarbeiten)
progress = widgets.IntProgress(value=0, min=0, max=max(gesamt_csvs,1), bar_style='info')
status   = widgets.Label(value='Starte...')
stop_btn = widgets.Button(description='⛔ Stop', button_style='danger')
display(widgets.HBox([progress, status, stop_btn]))

gestoppt = False
def stop(b):
    global gestoppt
    gestoppt = True
stop_btn.on_click(stop)

start    = time.time()
zaehler  = 0
gefunden = 0

for monat in zu_verarbeiten:
    if gestoppt:
        break
    monat_file = cache_sub / f'{monat}.parquet'
    writer     = None

    for csv_path in monate[monat]:
        if gestoppt:
            break
        df = pd.read_csv(csv_path, usecols=COLS, dtype={'station_uuid': str})
        df['date']    = pd.to_datetime(df['date'], utc=True)
        df['datum']   = df['date'].dt.date
        df['uhrzeit'] = df['date'].dt.strftime('%H:%M:%S')
        teil = df[df['station_uuid'] == STATION_UUID].copy()

        if not teil.empty:
            table = pa.Table.from_pandas(teil, preserve_index=False)
            if writer is None:
                writer = pq.ParquetWriter(monat_file, table.schema)
            writer.write_table(table)
            gefunden += len(teil)

        zaehler += 1
        vergangen   = time.time() - start
        verbleibend = (vergangen / zaehler) * (gesamt_csvs - zaehler)
        progress.value = zaehler
        status.value   = f'{monat} | {zaehler:,}/{gesamt_csvs:,} – {gefunden:,} Zeilen – ETA {int(verbleibend)}s'

    if writer:
        writer.close()

if gestoppt:
    progress.bar_style = 'warning'
    status.value = f'⛔ abgebrochen – bisherige Monate sind gecacht'
else:
    progress.bar_style = 'success'
    status.value = f'✅ fertig in {int(time.time()-start)}s – {gefunden:,} Zeilen'

# Alle gecachten Monate zusammensetzen
monat_files = sorted(cache_sub.glob('*.parquet'))
print(f'\nLade {len(monat_files)} Monatsdateien...')
station_prices = pd.concat([pd.read_parquet(f) for f in monat_files], ignore_index=True)
print(f'{len(station_prices):,} Zeilen ({monat_files[0].stem} – {monat_files[-1].stem})')
# Out:
# 143 Monate gesamt, 0 zu verarbeiten
# HBox(children=(IntProgress(value=0, bar_style='info', max=1), Label(value='Starte...'), Button(button_style='d…
# Lade 4 Monatsdateien...
# 4,162 Zeilen (2025-12 – 2026-03)

# %% [markdown]
# ## 4. Bereinigen

# %%
# ── 4. Bereinigen ─────────────────────────────────────────────────────────
df = station_prices.drop(columns=['date']).copy()

# Ausreißer entfernen (Preise außerhalb 0.50–3.00 €)
for col in ['diesel','e5','e10']:
    df[col] = df[col].where(df[col].between(0.50, 3.00))

# Duplikate raus
df = df.drop_duplicates().sort_values('datum').reset_index(drop=True)

print(f'{len(df):,} Zeilen nach Bereinigung')
print(f'Zeitraum: {df["datum"].min()} – {df["datum"].max()}')
display(df.head())
# Out:
# 4,162 Zeilen nach Bereinigung
# Zeitraum: 2025-12-01 – 2026-03-11
#                            station_uuid  diesel     e5    e10       datum  \
# 0  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.759  1.819  1.759  2025-12-01
# 1  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.619  1.729  1.669  2025-12-01
# 2  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.619  1.709  1.649  2025-12-01
# 3  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.569  1.709  1.649  2025-12-01
# 4  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.609  1.759  1.699  2025-12-01
#
#     uhrzeit
# 0  05:31:56
# 1  13:36:38
# 2  14:16:15
# 3  14:35:34
# 4  15:02:01

# %% [markdown]
# ## 5. Tagespreise

# %%
# ── 5. Tagespreise ────────────────────────────────────────────────────────
tagespreise = df.sort_values('datum').reset_index(drop=True)
print(f'{len(tagespreise)} Preisänderungen')
display(tagespreise.head(10))
# Out:
# 4162 Preisänderungen
#                            station_uuid  diesel     e5    e10       datum  \
# 0  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.759  1.819  1.759  2025-12-01
# 1  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.739  1.799  1.739  2025-12-01
# 2  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.729  1.789  1.729  2025-12-01
# 3  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.769  1.839  1.779  2025-12-01
# 4  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.669  1.839  1.779  2025-12-01
# 5  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.669  1.829  1.769  2025-12-01
# 6  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.669  1.819  1.759  2025-12-01
# 7  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.639  1.739  1.679  2025-12-01
# 8  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.769  1.879  1.819  2025-12-01
# 9  e1aefc4e-3ca1-4018-8d91-455b69d35d41   1.619  1.739  1.679  2025-12-01
#
#     uhrzeit
# 0  05:31:56
# 1  07:16:20
# 2  07:36:37
# 3  08:07:05
# 4  08:08:06
# 5  08:12:09
# 6  08:36:34
# 7  13:08:18
# 8  08:01:59
# 9  10:36:17

# %% [markdown]
# ## 6. Jahresübersicht

# %%
# ── 6. Jahresübersicht ────────────────────────────────────────────────────
df['jahr'] = pd.to_datetime(df['datum']).dt.year
jahres = df.groupby('jahr')[['diesel','e5','e10']].agg(['mean','min','max']).round(3)
display(jahres)
# Out:
#      diesel                   e5                  e10
#        mean    min    max   mean    min    max   mean    min    max
# jahr
# 2025  1.578  1.499  1.769  1.705  1.619  1.879  1.645  1.559  1.819
# 2026  1.761  1.579  2.299  1.837  1.709  2.199  1.777  1.649  2.139

# %% [markdown]
# ## 7. Quickplot

# %%
# ── 7. Quickplot ──────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(14, 5))

x = pd.to_datetime(tagespreise['datum'].astype(str) + ' ' + tagespreise['uhrzeit'])

# Tagesdurchschnitt für gleitenden Durchschnitt
tages_mean = df.groupby('datum')[['diesel','e5','e10']].mean()
tages_mean.index = pd.to_datetime(tages_mean.index)
rolling = tages_mean.rolling(7).mean()

for col, farbe, label in [('e5','tab:blue','Super E5'), ('e10','tab:green','Super E10'), ('diesel','tab:orange','Diesel')]:
    ax.plot(x, tagespreise[col], color=farbe, linewidth=0.8, alpha=0.4)
    ax.plot(rolling.index, rolling[col], color=farbe, linewidth=2, label=f'{label} (7-Tage-Ø)')


ax.set_title(f"{station_info['name']} – {station_info['street']} {station_info['house_number']}, {station_info['city']}")
ax.set_ylabel('Preis (€)')
ax.legend()
ax.grid(alpha=0.3)
fig.autofmt_xdate(rotation=45)
ax.xaxis.set_major_locator(plt.AutoLocator())

plt.tight_layout()
plt.savefig(EXPORT_DIR / f'{STATION_UUID}_preise.png', dpi=150)
plt.show()
print(f'Plot gespeichert → {EXPORT_DIR}')
# Out:
# Plot gespeichert → /media/rex/6DFF-26FE/Tankerkoenig/export

# %% [markdown]
# ## 8. Export

# %%
# ── 8. Export ─────────────────────────────────────────────────────────────
export_csv     = EXPORT_DIR / f'{STATION_UUID}_tagespreise.csv'
export_parquet = EXPORT_DIR / f'{STATION_UUID}_tagespreise.parquet'

tagespreise.to_csv(export_csv)
tagespreise.to_parquet(export_parquet)

print(f'✅ CSV     → {export_csv}')
print(f'✅ Parquet → {export_parquet}')
# Out:
# ✅ CSV     → /media/rex/6DFF-26FE/Tankerkoenig/export/e1aefc4e-3ca1-4018-8d91-455b69d35d41_tagespreise.csv
# ✅ Parquet → /media/rex/6DFF-26FE/Tankerkoenig/export/e1aefc4e-3ca1-4018-8d91-455b69d35d41_tagespreise.parquet
